# %% [markdown]
# <a href="https://colab.research.google.com/github/stanley1208/AI-Learning/blob/main/week2_day7_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([1,2,3,4,5])
y = np.array([3, 4, 2, 5, 6])
y=2*x+1+np.random.randn(5)

# %%
m=np.cov(x,y,bias=True)[0,1]/np.var(x)
b=y.mean()-m*x.mean()

print(f"best fit line: y= {m:.2f}x + {b:.2f}")


print(m,b)
# Out:
# best fit line: y= 1.37x + 2.51
# 1.3705796237804364 2.514042718777522

# %%
y_pred=m*x+b

# %%
plt.scatter(x,y,color='blue',label='Data points')
plt.plot(x,y_pred,color='red',label='Fitted line')
plt.title('Linear Regression')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()



plt.show()

# %%
mse=np.mean((y-y_pred)**2)
print("Mean Squared Error: ", round(mse,3))
# Out:
# Mean Squared Error:  1.5

# %%
# Out:
# [3 4 2 5 6] [2.6 3.3 4.  4.7 5.4]
